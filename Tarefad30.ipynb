# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusandiasmim/alp_python_2026-1/blob/main/Tarefad30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tarefa1

num = int(input("Digite um número inteiro positivo: "))

if num % 2 == 0:
    resultado = num ** 2
else:
    resultado = num ** 3

print(f"Resultado: {resultado}")
# Out:
# Digite um número inteiro positivo: 9
# Resultado: 729
