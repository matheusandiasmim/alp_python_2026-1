# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusandiasmim/alp_python_2026-1/blob/main/Tarefa30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tarefa3

preco = float(input("Digite o valor da venda: "))

print("1 - À vista")
print("2 - Cartão de débito")
print("3 - Cartão de crédito")

codigo = int(input("Escolha a forma de pagamento: "))

if codigo == 1:
    total = preco - (preco * 15 / 100)
    print(f"Valor final: {total}")

elif codigo == 2:
    total = preco - (preco * 10 / 100)
    print(f"Valor final: {total}")

elif codigo == 3:
    total = preco - (preco * 5 / 100)
    print(f"Valor final: {total}")

else:
    print("Código inválido")
