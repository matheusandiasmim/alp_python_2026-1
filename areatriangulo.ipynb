# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusandiasmim/alp_python_2026-1/blob/main/areatriangulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Base = float(input("Digite o valor da base: "))
Altura = float(input("Digite o valor da altura: "))

area = Base * Altura

print("A área do retângulo é:", area)
# Out:
# Digite o valor da base: 10
# Digite o valor da altura: 7
# A área do retângulo é: 70.0
